# %%
import pandas as pd
df = pd.read_excel("icici/icici_bank_final_posts.xlsx")

# %%
df = df[df.Spam==0.0]
df.drop(["Spam"],axis=1,inplace=True)
df
# Out:
#       Unnamed: 0                                           Messages  \
# 0            0.0  if banknifty loosing tomorrow then ICICI Bank ...
# 7            7.0  Buy ICICI Bank with target of 814 & Stop loss ...
# 8            8.0      icici bank buy on dips strong momentum seen..
# 9            9.0  Buy ICICI Bank with target of 816 & Stop loss ...
# 10          10.0  ICICI Bank will cross Rs.867 from where it cor...
# ...          ...                                                ...
# 1393      1393.0  Buy ICICI bank at 840 support 800 target 955 f...
# 1394      1394.0  ICICI bank available at attractive valuation b...
# 1398      1398.0  POSTED YESTERDAY AFTER FILLING THE GAP THE STO...
# 1400      1400.0  ICICI bank available at attractive valuation b...
# 1401      1401.0  Icici bank will perform on Monday.Axis is Weak...
#
#               Time Stamp
# 0    2022-02-10 20:46:01
# 7    2022-02-10 14:41:05
# 8    2022-02-10 14:25:29
# 9    2022-02-10 13:38:32
# ...
